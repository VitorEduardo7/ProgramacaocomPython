# %% [markdown]
# <a href="https://colab.research.google.com/github/cintiapinho/logicaprogramacaopython/blob/main/listastuplasdicio/Exercicio_LISTAS_07_08_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Exercícios utilizando Listas Python**

# %% [markdown]
# ## 1. Soma dos Elementos da Lista
# Dada uma lista de números, calcule a soma de todos os elementos.

# %%
# Seu código aqui...
lista = [1, 2, 3, 4, 5]

numeros = lista


soma = sum(numeros)


print("A soma dos elementos é:", soma)
# Out:
# A soma dos elementos é: 15

# %% [markdown]
# ## 2. Produto dos elementos da lista
# Dada uma lista de números, calcule o produto de todos os elementos.

# %%
# Seu código aqui...
lista2 = [1, 2, 3, 4, 5]
len(lista2)
# Out:
# 5

# %% [markdown]
# ## 3. Encontre o menor elemento
# Dada uma lista de números, encontre o menor elemento.

# %%
# Seu código aqui...
lista3 = [1, 2, 3, 4, 5]
min(lista3)
# Out:
# 1

# %% [markdown]
# ## 4. Encontre o maior elemento
# Dada uma lista de números, encontre o maior elemento.

# %%
# Seu código aqui...
lista4 = [1, 2, 3, 4, 5]
max(lista4)
# Out:
# 5

# %% [markdown]
# ## 5. Contar Ocorrências de um Elemento
# Dada uma lista de números e um número alvo, conte quantas vezes o alvo aparece na lista.

# %%
# Seu código aqui...
lista5 = [1, 2, 3, 4, 3, 2, 1]
num1 = lista5.count(4)
num2 = lista5.count(2)
print(num1)
print(num2)
# Out:
# 1
# 2

# %% [markdown]
# ## 6. Remover duplicatas
# Dada uma lista de números, crie uma nova lista sem elementos duplicados.

# %%
# Seu código aqui...

lista6 = [1, 2, 2, 3, 4, 4, 5]
lista6 = list(set(lista6))
print(lista6)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ## 7. Inverter uma lista
# Dada uma lista de números, inverta a ordem dos elementos.
#
# ---

# %%
# Seu código aqui...
lista6 = [1, 2, 3, 4, 5]
lista6.reverse()
print(lista6)
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# *texto em itálico*## 8. Intercalar Duas Listas
# Dadas duas listas de números, crie uma nova lista intercalando os elementos das duas listas.

# %%
# Seu código aqui...
lista81 = [1, 3, 5]
lista82 = [2, 4, 6]

# %% [markdown]
# ## 9. Somar Elementos Correspondentes de Duas Listas
# Dadas duas listas de números de mesmo tamanho, crie uma nova lista com a soma dos elementos correspondentes.

# %%
# Seu código aqui...
lista91 = [1, 2, 3]
lista92 = [4, 5, 6]

# %% [markdown]
# ## 10. Mover Zeros para o Fim
# Dada uma lista de números, mova todos os zeros para o final da lista.

# %%
# Seu código aqui...
lista10 = [0, 1, 0, 3, 12]

# %% [markdown]
# 11. Use o método len para imprimir o comprimento da string.

# %%
x = "Hello World"
print(len(x))

# %% [markdown]
# # 12. Obtenha o primeiro caractere da string txt.

# %%
txt = "Hello World"
x = txt[0]
print(x)

# %% [markdown]
# 13. Obtenha os caracteres do índice 2 ao índice 4 ( llo).

# %%
txt = "Hello World"
x = txt[2:5]
print(x)

# %% [markdown]
# 14. Converta o valor de txt para maiúsculas.

# %%
txt = "Hello World"
s.upper()

# %% [markdown]
# 15. Conte quantas vezes aparece a palavra "de" na string abaixo

# %%
txt = "Eu gosto de vijar, tomar vinho, de estudar estudar programação, de estudar Pyhon"
contador = txt.count('de')
print(contador)
# Out:
# 3

# %% [markdown]
# 16. Separe a frase abaixo toda vez que encontrar um vírgula

# %%
txt = "Eu gosto de vijar, tomar vinho, de estudar estudar programação, de estudar Pyhon"
separar = txt.split(',')
print(separar)
# Out:
# ['Eu gosto de vijar', ' tomar vinho', ' de estudar estudar programação', ' de estudar Pyhon']

# %% [markdown]
# 17. Peça ao usuário uma frase e substitua todas as ocorrências de espaço por “#”.

# %%
frase = input("Escreva uma frase: ")
frase = frase.replace(" ", "#")
print(frase)

# %% [markdown]
# 18. Faça um programa que retorne True se duas strings lidas do teclado são palíndromas mútuas, ou seja, se uma é igual à outra quando lida de traz para frente ou False, se não forem.
# Por exemplo: amor e roma

# %%
frase = input("Escreva uma palavra que seja palíndroma:")
frase = frase2[::-1]
if frase == frase2:
  print("true")
else:
  print("false")
# Out:
# Escreva uma palavra que seja palíndroma:amor
# false

# %% [markdown]
# 19.  Faça um programa que leia o nome do usuário e mostre o nome de traz para frente, utilizando somente letras maiúsculas.

# %%
nome = input("Escreva seu nome:")
nome.upper()
nome[::-1]

# %% [markdown]
# 20.  1) Crie uma tupla contendo três tipos diferentes de dados: um número, uma string e uma lista. Use um laço de repetição para acessar e imprimir cada item da tupla. Além disso, dentro do laço, acesse e imprima o segundo item da lista que está dentro da tupla.

# %%
dados = (24, "Cíntia",[1,2,3])

for i in dados:
  print(i)

# %% [markdown]
# 21.

# %%
minha_tupla = (42, "Vitor é daora", [1, 2, 3, 4])

for item in minha_tupla:
    print(item)
    if isinstance(item, list):
        print("Segundo item da lista:", item[1])

# %% [markdown]
# 22.
# Cadastro de Pessoas e Análise de Alturas
# 2) Solicite ao usuário para inserir o nome e a altura de várias pessoas. Preencha um dicionário com essas informações e depois encontre e imprima o nome e a altura da pessoa mais alta e da mais baixa.

# %%
pessoas = {}

while True:
    nome = input("Insira o nome da pessoa (ou digite 'sair' para encerrar): ")
    if nome.lower() == 'sair':
        break
    altura = float(input(f"Insira a altura de {nome} em metros: "))
    pessoas[nome] = altura

if pessoas:
    mais_alta = max(pessoas, key=pessoas.get)
    mais_baixa = min(pessoas, key=pessoas.get)

    print(f"A pessoa mais alta é {mais_alta} com {pessoas[mais_alta]} metros.")
    print(f"A pessoa mais baixa é {mais_baixa} com {pessoas[mais_baixa]} metros.")
else:
    print("Nenhuma pessoa foi cadastrada.")

# %% [markdown]
# 23. Lista, laços e Condicionais
# 3) Descrição: Crie uma lista com cinco números inteiros. Use um laço de repetição e uma condicional para imprimir apenas os números que são múltiplos de 3.

# %%
numeros = [45, 27, 212, 90, 302]

for numero in numeros:
    if numero % 3 == 0:
        print(numero)

# %% [markdown]
# 24. 4) Descrição: Crie uma string com uma frase. Use uma condicional para verificar se a frase contém a palavra "Python". Se sim, substitua a palavra "Python" por "programação" e imprima a nova frase.

# %%
frase = "Eu estou aprendendo Python."

if "Python" in frase:
    nova_frase = frase.replace("Python", "programação")
    print(nova_frase)
else:
    print("A palavra 'Python' não foi encontrada na frase.")

# %% [markdown]
# 25.  Simule uma situação de alfândega onde o funcionário cadastra itens novos encontrados na mala de uma pessoa que veio de uma viagem internacional. Após o cadastro de todos os itens, o programa imprime uma nota com todos os itens e seus preços, calcula o valor total e, se o valor total ultrapassar 500 dólares, calcula o valor de 60% a ser pago.

# %%
itens = {}

while True:
    item = input("Nome do item (ou 'sairfe' para encerrar): ")
    if item.lower() == 'sair':
        break
    preco = float(input(f"Preço de {item} em dólares: "))
    itens[item] = preco

valor_total = sum(itens.values())

print("\nNota da Alfândega:")
for item, preco in itens.items():
    print(f"{item}: ${preco:.2f}")

print(f"\nValor total: ${valor_total:.2f}")

if valor_total > 500:
    taxa = valor_total * 0.60
    print(f"\nValor a ser pago (60% do total): ${taxa:.2f}")
else:
    print("Não há taxa a ser paga.")

# %% [markdown]
# 26. 6) Você vai criar um programa em Python para analisar um texto e identificar palavras que expressam pensamentos negativos. Para isso, você usará uma lista de palavras negativas fornecida e verificará quais dessas palavras estão presentes no texto fornecido pelo usuário. Exemplo de palavras negtivas, acrescente mais na lista: # Lista de palavras negativas palavras_negativas = ['triste', 'deprimido', 'ansioso', 'desapontado', 'frustrado']

# %%
palavras_negativas = ['triste', 'deprimido', 'ansioso', 'desapontado', 'frustrado']

texto = input("Digite um texto: ").lower()

for palavra in palavras_negativas:
    if palavra in texto:
        print(f"Palavra negativa encontrada: {palavra}")
